# %%
import dotenv; dotenv.load_dotenv()
import os; os.environ["DATA_PATH"] = "../data"
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from system_prompt import create_system_prompt
from tools import my_tools

# %%
llm_model = ChatOpenAI(model=os.getenv('LLM_MODEL'), temperature=0)
toolbox = my_tools(['vector_store', 'database'])
prompt = create_system_prompt()

agent = create_agent(
    llm_model,
    toolbox,
    system_prompt=prompt,
)
# Out:
# ../data\whu_schema.json already exists.
# Loading schema from existing file.

# %%
query = "我要在武汉大学内有几栋建筑"


for event in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# 我要在武汉大学内有几栋建筑
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_list_tables (call_ae4OM38rq08lmdu4nmWq7Frq)
#  Call ID: call_ae4OM38rq08lmdu4nmWq7Frq
#   Args:
# ================================= Tool Message =================================
# Name: sql_db_list_tables
#
# osm2pgsql_properties, planet_osm_line, planet_osm_point, planet_osm_polygon, planet_osm_roads, spatial_ref_sys
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_schema (call_pOXTszd1vuaJ5QZWrQAl6aRU)
#  Call ID: call_pOXTszd1vuaJ5QZWrQAl6aRU
#   Args:
#     table_names: planet_osm_polygon
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE planet_osm_polygon (
# 	osm_id BIGINT,
# 	access TEXT,
# 	"addr:housename" TEXT,
# 	"addr:housenumber" TEXT,
# 	"addr:interpolation" TEXT,
# 	admin_level TEXT,
# 	aerialway TEXT,
# 	aeroway TEXT,
# 	amenity TEXT,
# 	area TEXT,
# 	barrier TEXT,
# 	bicycle TEXT,
# 	brand TEXT,
# 	bridge TEXT,
# 	boundary TEXT,
# 	building TEXT,
# 	construction TEXT,
# 	covered TEXT,
# 	culvert TEXT,
# 	cutting TEXT,
# 	denomination TEXT,
# 	disused TEXT,
# 	embankment TEXT,
# 	foot TEXT,
# 	"generator:source" TEXT,
# 	harbour TEXT,
# 	highway TEXT,
# 	historic TEXT,
# 	horse TEXT,
# 	intermittent TEXT,
# 	junction TEXT,
# 	landuse TEXT,
# 	layer TEXT,
# 	leisure TEXT,
# 	lock TEXT,
# 	man_made TEXT,
# 	military TEXT,
# 	motorcar TEXT,
# 	name TEXT,
# 	"natural" TEXT,
# 	office TEXT,
# 	oneway TEXT,
# 	operator TEXT,
# 	place TEXT,
# 	population TEXT,
# 	power TEXT,
# 	power_source TEXT,
# 	public_transport TEXT,
# 	railway TEXT,
# 	ref TEXT,
# 	religion TEXT,
# 	route TEXT,
# 	service TEXT,
# 	shop TEXT,
# 	sport TEXT,
# 	surface TEXT,
# 	toll TEXT,
# 	tourism TEXT,
# 	"tower:type" TEXT,
# 	tracktype TEXT,
# 	tunnel TEXT,
# 	water TEXT,
# 	waterway TEXT,
# 	wetland TEXT,
# 	width TEXT,
# 	wood TEXT,
# 	z_order INTEGER,
# 	way_area REAL,
# 	way geometry(GEOMETRY,3857)
# )
#
# /*
# 3 rows from planet_osm_polygon table:
# osm_id	access	addr:housename	addr:housenumber	addr:interpolation	admin_level	aerialway	aeroway	amenity	area	barrier	bicycle	brand	bridge	boundary	building	construction	covered	culvert	cutting	denomination	disused	embankment	foot	generator:source	harbour	highway	historic	horse	intermittent	junction	landuse	layer	leisure	lock	man_made	military	motorcar	name	natural	office	oneway	operator	place	population	power	power_source	public_transport	railway	ref	religion	route	service	shop	sport	surface	toll	tourism	tower:type	tracktype	tunnel	water	waterway	wetland	width	wood	z_order	way_area	way
# 1036845883	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	grass	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	0	6768.48	0103000020110f000001000000070000001f747cfed84768415d3fe9e5b2444b411b0a4d23da4768413b49c89588444b41c7
# 153753514	None	None	None	None	None	None	None	None	None	None	None	None	None	None	university	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	工学部9号教学楼	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	0	4561.42	0103000020110f000001000000150000000aea6fe2ea476841e2764cbaa2444b413fd7dfd7eb4768415ed6f29884444b412e
# 1387843579	None	None	None	None	None	None	None	None	None	None	None	None	None	None	yes	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	0	212.934	0103000020110f000001000000050000008daec6ebf9476841d16fcb02a6444b41a25ab838fa476841ad46fbfa9b444b418e
# */
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve_context (call_gSX5r8fXEcaR5H4OZZjU17EM)
#  Call ID: call_gSX5r8fXEcaR5H4OZZjU17EM
#   Args:
#     query: How to find buildings within a specific polygon or area using PostGIS?
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'source': 'data/postgis-3.6-en.pdf', 'creator': 'DBLaTeX-0.3.12', 'trapped': '/False', 'producer': 'pdfTeX-1.40.21', 'page_label': '84', 'creationdate': '2025-10-15T21:40:24+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020/Debian) kpathsea version 6.3.2', 'subject': '', 'author': '', 'total_pages': 946, 'moddate': '2025-10-15T21:40:24+00:00', 'title': 'PostGIS 3.6.1dev Manual', 'page': 110, 'keywords': ''}
# Content: ARRAY( SELECT w.geom
# FROM waterlines w
# WHERE ST_Within(w.geom, p.geom)
# AND ST_IsClosed(w.geom)))
# ELSE p.geom
# END AS geom
# FROM provinces p;
# See Also
# ST_BuildArea ST_Polygon
# 7.3.8 ST_Point
# ST_Point — Creates a Point with X, Y and SRID values.
#
# Source: {'subject': '', 'producer': 'pdfTeX-1.40.21', 'total_pages': 946, 'creator': 'DBLaTeX-0.3.12', 'author': '', 'creationdate': '2025-10-15T21:40:24+00:00', 'title': 'PostGIS 3.6.1dev Manual', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020/Debian) kpathsea version 6.3.2', 'moddate': '2025-10-15T21:40:24+00:00', 'source': 'data/postgis-3.6-en.pdf', 'keywords': '', 'page_label': '712', 'trapped': '/False', 'page': 738}
# Content: PostGIS 3.6.1dev Manual 712 / 919
# Example: Summarize pixels that intersect buildings of interest
# This example took 574ms on PostGIS windows 64-bit with all of Boston Buildings and aerial Tiles (tiles each 150x150 pixels ~
# 134,000 tiles), ~102,000 building records
# WITH
# -- our features of interest
# feat AS (SELECT gid As building_id, geom_26986 As geom FROM buildings AS b
# WHERE gid IN(100, 103,150)
# ),
# -- clip band 2 of raster tiles to boundaries of builds
# -- then get stats for these clipped regions
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query (call_LZfvunQnmBAOVc9qrcLkdbGa)
#  Call ID: call_LZfvunQnmBAOVc9qrcLkdbGa
#   Args:
#     query: SELECT name FROM planet_osm_polygon WHERE building IS NOT NULL AND ST_Intersects(way, (SELECT way FROM planet_osm_polygon WHERE name LIKE '%武汉大学%' LIMIT 1)) LIMIT 5;
# ================================= Tool Message =================================
# Name: sql_db_query
#
# [('武汉大学信息中心',)]
# ================================== Ai Message ==================================
#
# 在武汉大学内有建筑物，示例中有一栋名为“武汉大学信息中心”的建筑。您需要更多建筑名称吗？
