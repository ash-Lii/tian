# %%
# 查询数据库模式
import os
from sqlalchemy import create_engine, inspect
from geoalchemy2 import Geometry

dbName = "parks"

dburl = os.getenv("DB_URL") + dbName + os.getenv("DB_PARMS")
engine = create_engine(dburl)
inspector = inspect(engine)

custom_schema = {}

for table_name in inspector.get_table_names():
    columns = inspector.get_columns(table_name)
    col_list = []
    for col in columns:
        # 类型转换为字符串，防止类型对象无法序列化
        col_type = str(col['type'])
        col_list.append({
            "name": col['name'],
            "type": col_type,
        })
    custom_schema[table_name] = {"columns": col_list}

# 保存到文件
import json
with open("data/schema.json", "w") as f:
    json.dump(custom_schema, f, indent=4)

# 打印结果
import pprint
pprint.pprint(custom_schema)
# Out:
# {'facilities': {'columns': [{'name': 'facility_id', 'type': 'VARCHAR'},
#                             {'name': 'park_id', 'type': 'VARCHAR'},
#                             {'name': 'facility_name', 'type': 'VARCHAR'},
#                             {'name': 'facility_type', 'type': 'VARCHAR'},
#                             {'name': 'location_wkt',
#                              'type': 'geometry(GEOMETRY,-1)'}]},
#  'maintenance_logs': {'columns': [{'name': 'log_id', 'type': 'VARCHAR'},
#                                   {'name': 'facility_id', 'type': 'VARCHAR'},
#                                   {'name': 'technician', 'type': 'VARCHAR'},
#                                   {'name': 'status', 'type': 'VARCHAR'},
#                                   {'name': 'date', 'type': 'DATE'},
#                                   {'name': 'maintenance_notes',
#                                    'type': 'TEXT'}]},
#  'parks': {'columns': [{'name': 'park_id', 'type': 'VARCHAR'},
#                        {'name': 'park_name', 'type': 'VARCHAR'},
#                        {'name': 'area_name', 'type': 'VARCHAR'},
#                        {'name': 'boundary_wkt',
#                         'type': 'geometry(GEOMETRY,-1)'}]},
#  'spatial_ref_sys': {'columns': [{'name': 'srid', 'type': 'INTEGER'},
#                                  {'name': 'auth_name', 'type': 'VARCHAR(256)'},
#                                  {'name': 'auth_srid', 'type': 'INTEGER'},
#                                  {'name': 'srtext', 'type': 'VARCHAR(2048)'},
#                                  {'name': 'proj4text',
#                                   'type': 'VARCHAR(2048)'}]}}

# %%
# 创建向量数据库检索工具

from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings  # 或你自己的 embedding

# 1. 创建 embedding 实例
embeddings = OpenAIEmbeddings(model ='text-embedding-3-small')

# 2. 加载已保存的向量库
vectordb = Chroma(
    persist_directory="chroma_db",
    embedding_function=embeddings
)

from langchain_core.tools import create_retriever_tool

retriever = vectordb.as_retriever(search_kwargs={"k": int(os.environ.get("VECTOR_QURY_TOP_K"))})

retriever_tool = create_retriever_tool(
    retriever,
    name="pdf_knowledge_retriever",
    description="A tool for retrieving relevant information",
)

# %%
from langchain_community.agent_toolkits.sql.toolkit import SQLDatabaseToolkit
from langchain_community.utilities import SQLDatabase
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model='gpt-4.1-mini', temperature=0)

toolkit = SQLDatabaseToolkit(db = SQLDatabase.from_uri(dburl), 
                             llm = model, 
                             custom_schema = custom_schema)

tools = toolkit.get_tools()
tools.append(retriever_tool)

# %%
# 提示词
system_prompt = """
    You are an agent designed to interact with a SQL database.
    Given an input question, create a syntactically correct {dialect} query to run,
    then look at the results of the query and return the answer. Unless the user
    specifies a specific number of examples they wish to obtain, always limit your
    query to at most {top_k} results.

    This is the schema of the database: {schema}

    You can order the results by a relevant column to return the most interesting
    examples in the database. Never query for all the columns from a specific table,
    only ask for the relevant columns given the question.

    You MUST double check your query before executing it. If you get an error while
    executing a query, rewrite the query and try again.

    DO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the
    database.

    To start you should ALWAYS look at the tables in the database to see what you
    can query. Do NOT skip this step.

    Then you should query the schema of the most relevant tables.

""".format(
    dialect=os.environ.get("DIALECT"),
    top_k=os.environ.get("DB_QURY_TOP_K"),
    schema=custom_schema,
)

# %%
# 使用 LangGraph 构建 agent

from langchain.agents import create_agent
from langgraph.graph import StateGraph

agent = create_agent(
    model=model,
    tools=tools,
    system_prompt=system_prompt,
)

graph = StateGraph(state_schema=str)

graph.add_node("agent", agent)

graph.set_entry_point("agent")  # 入口节点
graph.set_finish_point("agent") # 结束节点

app = graph.compile()

# %%
# 提问回答

question = "生成数据库er图"
# qu = "植物生长需要什么条件？"


for step in app.stream(
    {"messages": [{"role": "user", "content": question}]},
    stream_mode="values",
):
    message = step['messages']
    if type(message[0]) == dict:
        pass
    else:
        for msg in message:
            msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 生成数据库er图
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_list_tables (call_qvoMsapXYVJ5k3l9Z6BTDrNe)
#  Call ID: call_qvoMsapXYVJ5k3l9Z6BTDrNe
#   Args:
# ================================= Tool Message =================================
# Name: sql_db_list_tables
#
# facilities, maintenance_logs, parks, spatial_ref_sys
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_schema (call_HQXhUVw7DrUTTGDgyOWIHzGM)
#  Call ID: call_HQXhUVw7DrUTTGDgyOWIHzGM
#   Args:
#     table_names: facilities
#   sql_db_schema (call_auYrRXcGKYrzWcNw29MTtAqU)
#  Call ID: call_auYrRXcGKYrzWcNw29MTtAqU
#   Args:
#     table_names: maintenance_logs
#   sql_db_schema (call_szjCGQllErZYFfEMWssnTVeX)
#  Call ID: call_szjCGQllErZYFfEMWssnTVeX
#   Args:
#     table_names: parks
#   sql_db_schema (call_lo4JXFJOFZOhBjvbPAAvu2aN)
#  Call ID: call_lo4JXFJOFZOhBjvbPAAvu2aN
#   Args:
#     table_names: spatial_ref_sys
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE facilities (
# 	facility_id VARCHAR NOT NULL,
# 	park_id VARCHAR,
# 	facility_name VARCHAR,
# 	facility_type VARCHAR,
# 	location_wkt geometry(GEOMETRY,-1),
# 	CONSTRAINT facilities_pkey PRIMARY KEY (facility_id),
# 	CONSTRAINT facilities_park_id_fkey FOREIGN KEY(park_id) REFERENCES parks (park_id)
# )
#
# /*
# 3 rows from facilities table:
# facility_id	park_id	facility_name	facility_type	location_wkt
# F001	P001	休息凉亭1号	休息凉亭	0101000000b5c39d186c8e5c4023995f9c82953e40
# F002	P002	夜间照明系统1号	夜间照明系统	01010000004e6c48159f945c4018ffed014ba73e40
# F003	P003	科普展示牌1号	科普展示牌	01010000007c07d69cc1995c409b0694c854b73e40
# */
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE maintenance_logs (
# 	log_id VARCHAR NOT NULL,
# 	facility_id VARCHAR,
# 	technician VARCHAR,
# 	status VARCHAR,
# 	date DATE,
# 	maintenance_notes TEXT,
# 	CONSTRAINT maintenance_logs_pkey PRIMARY KEY (log_id),
# 	CONSTRAINT maintenance_logs_facility_id_fkey FOREIGN KEY(facility_id) REFERENCES facilities (facility_id)
# )
#
# /*
# 3 rows from maintenance_logs table:
# log_id	facility_id	technician	status	date	maintenance_notes
# M001	F001	高强	需维修	2025-01-07	 接到市民投诉卫生状况差
# M002	F001	张伟	已停用	2025-04-05	 设备达到报废年限
# M003	F001	张伟	维修中	2025-07-04	 正在更换地板
# */
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE parks (
# 	park_id VARCHAR NOT NULL,
# 	park_name VARCHAR,
# 	area_name VARCHAR,
# 	boundary_wkt geometry(GEOMETRY,-1),
# 	CONSTRAINT parks_pkey PRIMARY KEY (park_id)
# )
#
# /*
# 3 rows from parks table:
# park_id	park_name	area_name	boundary_wkt
# P001	南湖湿地公园	洪山区	01030000000100000005000000a2f8e582318e5c409736969cfc943e405a176b6e838e5c409736969cfc943e405a176b6e83
# P002	纱帽江滩公园	汉南区	010300000001000000050000006a1f54d588945c40910e7736f6a63e40223ed9c0da945c40910e7736f6a63e40223ed9c0da
# P003	梁子湖风景区	江夏区	01030000000100000005000000ed9ee639a8995c40e899ca22fcb63e40a5bd6b25fa995c40e899ca22fcb63e40a5bd6b25fa
# */
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE spatial_ref_sys (
# 	srid INTEGER NOT NULL,
# 	auth_name VARCHAR(256),
# 	auth_srid INTEGER,
# 	srtext VARCHAR(2048),
# 	proj4text VARCHAR(2048),
# 	CONSTRAINT spatial_ref_sys_pkey PRIMARY KEY (srid),
# 	CONSTRAINT spatial_ref_sys_srid_check CHECK (srid > 0 AND srid <= 998999)
# )
#
# /*
# 3 rows from spatial_ref_sys table:
# srid	auth_name	auth_srid	srtext	proj4text
# 2000	EPSG	2000	PROJCS["Anguilla 1957 / British West Indies Grid",GEOGCS["Anguilla 1957",DATUM["Anguilla_1957",SPHER	+proj=tmerc +lat_0=0 +lon_0=-62 +k=0.9995000000000001 +x_0=400000 +y_0=0 +ellps=clrk80 +units=m +no_
# 2001	EPSG	2001	PROJCS["Antigua 1943 / British West Indies Grid",GEOGCS["Antigua 1943",DATUM["Antigua_1943",SPHEROID	+proj=tmerc +lat_0=0 +lon_0=-62 +k=0.9995000000000001 +x_0=400000 +y_0=0 +ellps=clrk80 +towgs84=-255
# 2002	EPSG	2002	PROJCS["Dominica 1945 / British West Indies Grid",GEOGCS["Dominica 1945",DATUM["Dominica_1945",SPHER	+proj=tmerc +lat_0=0 +lon_0=-62 +k=0.9995000000000001 +x_0=400000 +y_0=0 +ellps=clrk80 +towgs84=725,
# */
# ================================== Ai Message ==================================
#
# 根据数据库中的表结构和字段信息，生成的ER图描述如下：
#
# 实体：
# 1. parks（公园）
#    - park_id (主键)
#    - park_name
#    - area_name
#    - boundary_wkt (几何边界)
#
# 2. facilities（设施）
#    - facility_id (主键)
#    - park_id (外键，关联parks表的park_id)
#    - facility_name
#    - facility_type
#    - location_wkt (几何位置)
#
# 3. maintenance_logs（维护日志）
#    - log_id (主键)
#    - facility_id (外键，关联facilities表的facility_id)
#    - technician
#    - status
#    - date
#    - maintenance_notes
#
# 4. spatial_ref_sys（空间参考系统）
#    - srid (主键)
#    - auth_name
#    - auth_srid
#    - srtext
#    - proj4text
#
# 关系：
# - parks 与 facilities 是一对多关系（一个公园可以有多个设施）
# - facilities 与 maintenance_logs 是一对多关系（一个设施可以有多条维护日志）
#
# 如果您需要，我可以帮您生成ER图的图形文件或更详细的图形描述。您需要吗？

# %%
# 提问回答

question = "最南边的公园是什么，距离他最近的设施最近的维护日期是什么，设施是什么？"
# qu = "植物生长需要什么条件？"


for step in app.stream(
    {"messages": [{"role": "user", "content": question}]},
    stream_mode="values",
):
    message = step['messages']
    if type(message[0]) == dict:
        pass
    else:
        for msg in message:
            msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 最南边的公园是什么，距离他最近的设施最近的维护日期是什么
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_list_tables (call_vkOufwxNzOvK9M78dMx4kJiG)
#  Call ID: call_vkOufwxNzOvK9M78dMx4kJiG
#   Args:
# ================================= Tool Message =================================
# Name: sql_db_list_tables
#
# facilities, maintenance_logs, parks, spatial_ref_sys
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_schema (call_mOI00yPdAq8GA4K4m6lzpOZi)
#  Call ID: call_mOI00yPdAq8GA4K4m6lzpOZi
#   Args:
#     table_names: parks
#   sql_db_schema (call_1GePqzO852Df4odAy1rUuNZZ)
#  Call ID: call_1GePqzO852Df4odAy1rUuNZZ
#   Args:
#     table_names: facilities
#   sql_db_schema (call_JJI6p3FDkIkvVq6VF2w1U0zq)
#  Call ID: call_JJI6p3FDkIkvVq6VF2w1U0zq
#   Args:
#     table_names: maintenance_logs
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE parks (
# 	park_id VARCHAR NOT NULL,
# 	park_name VARCHAR,
# 	area_name VARCHAR,
# 	boundary_wkt geometry(GEOMETRY,-1),
# 	CONSTRAINT parks_pkey PRIMARY KEY (park_id)
# )
#
# /*
# 3 rows from parks table:
# park_id	park_name	area_name	boundary_wkt
# P001	南湖湿地公园	洪山区	01030000000100000005000000a2f8e582318e5c409736969cfc943e405a176b6e838e5c409736969cfc943e405a176b6e83
# P002	纱帽江滩公园	汉南区	010300000001000000050000006a1f54d588945c40910e7736f6a63e40223ed9c0da945c40910e7736f6a63e40223ed9c0da
# P003	梁子湖风景区	江夏区	01030000000100000005000000ed9ee639a8995c40e899ca22fcb63e40a5bd6b25fa995c40e899ca22fcb63e40a5bd6b25fa
# */
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE facilities (
# 	facility_id VARCHAR NOT NULL,
# 	park_id VARCHAR,
# 	facility_name VARCHAR,
# 	facility_type VARCHAR,
# 	location_wkt geometry(GEOMETRY,-1),
# 	CONSTRAINT facilities_pkey PRIMARY KEY (facility_id),
# 	CONSTRAINT facilities_park_id_fkey FOREIGN KEY(park_id) REFERENCES parks (park_id)
# )
#
# /*
# 3 rows from facilities table:
# facility_id	park_id	facility_name	facility_type	location_wkt
# F001	P001	休息凉亭1号	休息凉亭	0101000000b5c39d186c8e5c4023995f9c82953e40
# F002	P002	夜间照明系统1号	夜间照明系统	01010000004e6c48159f945c4018ffed014ba73e40
# F003	P003	科普展示牌1号	科普展示牌	01010000007c07d69cc1995c409b0694c854b73e40
# */
# ================================= Tool Message =================================
# Name: sql_db_schema
#
#
# CREATE TABLE maintenance_logs (
# 	log_id VARCHAR NOT NULL,
# 	facility_id VARCHAR,
# 	technician VARCHAR,
# 	status VARCHAR,
# 	date DATE,
# 	maintenance_notes TEXT,
# 	CONSTRAINT maintenance_logs_pkey PRIMARY KEY (log_id),
# 	CONSTRAINT maintenance_logs_facility_id_fkey FOREIGN KEY(facility_id) REFERENCES facilities (facility_id)
# )
#
# /*
# 3 rows from maintenance_logs table:
# log_id	facility_id	technician	status	date	maintenance_notes
# M001	F001	高强	需维修	2025-01-07	 接到市民投诉卫生状况差
# M002	F001	张伟	已停用	2025-04-05	 设备达到报废年限
# M003	F001	张伟	维修中	2025-07-04	 正在更换地板
# */
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query (call_MjouBrK7aKJpAhRWvPOgveUD)
#  Call ID: call_MjouBrK7aKJpAhRWvPOgveUD
#   Args:
#     query: -- Find the southernmost park
# SELECT park_id, park_name, ST_Y(ST_Centroid(boundary_wkt)) AS latitude
# FROM parks
# ORDER BY latitude ASC
# LIMIT 1;
# ================================= Tool Message =================================
# Name: sql_db_query
#
# [('P038', '堤角公园', 30.385256292863758)]
# ================================== Ai Message ==================================
# Tool Calls:
#   sql_db_query (call_7OYGRrpHaxLBuSAHnVTVu8B0)
#  Call ID: call_7OYGRrpHaxLBuSAHnVTVu8B0
#   Args:
#     query: -- Find the facility closest to the southernmost park (P038) and get the most recent maintenance date for that facility
# WITH southernmost_park AS (
#   SELECT boundary_wkt FROM parks WHERE park_id = 'P038'
# ), closest_facility AS (
#   SELECT f.facility_id, f.facility_name, f.location_wkt
#   FROM facilities f, southernmost_park sp
#   ORDER BY ST_Distance(f.location_wkt, ST_Centroid(sp.boundary_wkt))
#   LIMIT 1
# )
# SELECT cf.facility_id, cf.facility_name, MAX(ml.date) AS most_recent_maintenance_date
# FROM closest_facility cf
# LEFT JOIN maintenance_logs ml ON cf.facility_id = ml.facility_id
# GROUP BY cf.facility_id, cf.facility_name;
# ================================= Tool Message =================================
# Name: sql_db_query
#
# [('F056', '塑胶跑道3号', datetime.date(2025, 1, 29))]
# ================================== Ai Message ==================================
#
# 最南边的公园是堤角公园，距离它最近的设施是塑胶跑道3号，该设施最近的维护日期是2025年1月29日。
